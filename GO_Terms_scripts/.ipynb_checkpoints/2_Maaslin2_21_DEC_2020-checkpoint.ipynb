# %% [markdown]
# # Maaslin 2 Analysis
# ###  COVIRT19 microbial subgroup seqscreen analysis
# #### Date : 21 DEC 2020
# #### Maintained by :
#     Jochum, Michael D.
#     Baylor College of Medicine
#     michael.jochum@bcm.edu

# %% [markdown]
# #### The purpose of this code is to:
# - identify GO terms assocaited with COVID19 via maaslin2

# %% [markdown]
# - load the libraries
# - set the environment
# - import the data from the dmm clustering analysis

# %%
library(tidyverse)
library(phyloseq)
library(Maaslin2)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
setwd('/home/jovyan/work/microbial/GO_term_analysis/16_DEC_2020_dmm_troubleshooting_Lee/')

# %%
load(file = "./images/1_dmm.RDA")

# %% [markdown]
# Transform GO Terms counts to relative abundances

# %%
term_pseq_no_neg_comp<-microbiome::transform(x = term_pseq_no_neg,transform = "compositional")

# %%
library(microbiome)
# Out:
# microbiome R package (microbiome.github.com)
#
#
#
#  Copyright (C) 2011-2020 Leo Lahti,
#     Sudarshan Shetty et al. <microbiome.github.io>
#
#
#
# Attaching package: ‘microbiome’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha
#
#
# The following object is masked from ‘package:base’:
#
#     transform

# %% [markdown]
# # MaAsLIN2

# %%
df_input_data<-data.frame(t(otu_table(term_pseq_no_neg_comp)))
df_input_metadata<-data.frame(sample_data(term_pseq_no_neg_comp))

# %%
dim(df_input_data)
# Out:
# [1]    86 13534

# %%
case_norm<-Maaslin2(
  input_data = df_input_data,
  input_metadata = df_input_metadata,
  output="./results/terms_vs_case_comp_norm",
  min_abundance = 0.01, 
  min_prevalence = 0.1, 
  normalization = "CLR",
  transform = "NONE",
  analysis_method = "LM",
  max_significance = 0.05,
  random_effects = c("sample_name","publication"),
  fixed_effects = c("case"),
  correction="BH",
  standardize = TRUE,
  cores = 48,
  plot_heatmap = TRUE,
  plot_scatter = TRUE,
  heatmap_first_n =num,
 reference="case,COVID19")
# Out:
# [1] "Warning: Deleting existing log file: ./results/terms_vs_case_comp_norm/maaslin2.log"
# 2021-02-02 17:41:34 INFO::Writing function arguments to log file
# 2021-02-02 17:41:34 INFO::Verifying options selected are valid
# 2021-02-02 17:41:34 INFO::Determining format of input files
# 2021-02-02 17:41:34 INFO::Input format is data samples as rows and metadata samples as rows
# 2021-02-02 17:41:35 INFO::Formula for random effects: expr ~ (1 | sample_name) + (1 | publication)
# 2021-02-02 17:41:35 INFO::Formula for fixed effects: expr ~  case
# 2021-02-02 17:41:35 INFO::Filter data based on min abundance and min prevalence
# 2021-02-02 17:41:35 INFO::Total samples in data: 86
# 2021-02-02 17:41:35 INFO::Min samples required with min abundance for a feature not to be filtered: 8.600000
# 2021-02-02 17:41:35 INFO::Total filtered features: 13493
# 2021-02-02 17:41:35 INFO::Filtered feature names from abundance and prevalence filtering: GO.0000002.mitochondrial.genome.maintenance.mitochondrial.genome.maintenance, GO.0000003.reproduction.reproduction, GO.0000006.high.affinity.zinc.transmembrane.transporter.activity.high.affinity.zinc.transmembrane.transporter.activity, GO.0000009.alpha.1.6.mannosyltransferase.activity.alpha.1.6.mannosyltransferase.activity, GO.0000011.vacuole.inheritance.vacuole.inheritance, GO.0000014.single.stranded.DNA.endodeoxyribonuclease.activity.single.stranded.DNA.endodeoxyribonuclease.activity, GO.0000018.regulation.of.DNA.recombination.regulation.of.DNA.recombination, GO.0000019.regulation.of.mitotic.recombination.regulation.of.mitotic.recombination, GO.0000023.maltose.metabolic.process.maltose.metabolic.process, GO.0000025.maltose.catabolic.process.maltose.catabolic.process, GO.0000026.alpha.1.2.mannosyltransferase.activity.alpha.1.2.mannosyltransferase.activity, GO.0000027.ribosomal.large.subunit.assembly.ribosomal.large.subunit.assembly, GO.0000028.ribosomal.small.subunit.assembly.ribosomal.small.subunit.assembly, GO.0000030.mannosyltransferase.activity.mannosyltransferase.activity, GO.0000032.cell.wall.mannoprotein.biosynthetic.process.cell.wall.mannoprotein.biosynthetic.process, GO.0000033.alpha.1.3.mannosyltransferase.activity.alpha.1.3.mannosyltransferase.activity, GO.0000034.adenine.deaminase.activity.adenine.deaminase.activity, GO.0000035.acyl.binding.acyl.binding, GO.0000036.acyl.carrier.activity.acyl.carrier.activity, GO.0000038.very.long.chain.fatty.acid.metabolic.process.very.long.chain.fatty.acid.metabolic.process, GO.0000041.transition.metal.ion.transport.transition.metal.ion.transport, GO.0000045.autophagosome.assembly.autophagosome.assembly, GO.0000048.peptidyltransferase.activity.peptidyltransferase.activity, GO.0000049.tRNA.binding.tRNA.binding, GO.0000050.urea.cycle.urea.cycle, GO.0000052.citrulline.metabolic.process.citrulline.metabolic.process, GO.0000053.argininosuccinate.metabolic.process.argininosuccinate.metabolic.process, GO.0000054.ribosomal.subunit.export.from.nucleus.ribosomal.subunit.export.from.nucleus, GO.0000055.ribosomal.large.subunit.export.from.nucleus.ribosomal.large.subunit.export.from.nucleus, GO.0000062.fatty.acyl.CoA.binding.fatty.acyl.CoA.binding, GO.0000064.L.ornithine.transmembrane.transporter.activity.L.ornithine.transmembrane.transporter.activity, GO.0000070.mitotic.sister.chromatid.segregation.mitotic.sister.chromatid.segregation, GO.0000075.cell.cycle.checkpoint.cell.cycle.checkpoint, GO.0000076.DNA.replication.checkpoint.DNA.replication.checkpoint, GO.0000077.DNA.damage.checkpoint.DNA.damage.checkpoint, GO.0000079.regulation.of.cyclin.dependent.protein.serine.threonine.kinase.activity.regulation.of.cyclin.dependent.protein.serine.threonine.kinase.activity, GO.0000082.G1.S.transition.of.mitotic.cell.cycle.G1.S.transition.of.mitotic.cell.cycle, GO.0000083.regulation.of.transcription.involved.in.G1.S.transition.of.mitotic.cell.cycle.regulation.of.transcription.involved.in.G1.S.transition.of.mitotic.cell.cycle, GO.0000086.G2.M.transition.of.mitotic.cell.cycle.G2.M.transition.of.mitotic.cell.cycle, GO.0000096.sulfur.amino.acid.metabolic.process.sulfur.amino.acid.metabolic.process, GO.0000097.sulfur.amino.acid.biosynthetic.process.sulfur.amino.acid.biosynthetic.process, GO.0000098.sulfur.amino.acid.catabolic.process.sulfur.amino.acid.catabolic.process, GO.0000099.sulfur.amino.acid.transmembrane.transporter.activity.sulfur.amino.acid.transmembrane.transporter.activity, GO.0000100.S.methylmethionine.transmembrane.transporter.activity.S.methylmethionine.transmembrane.transporter.activity, GO.0000101.sulfur.amino.acid.transport.sulfur.amino.acid.transport, GO.0000102.L.methionine.secondary.active.transmembrane.transporter.activity.L.methionine.secondary.active.transmembrane.transporter.activity, GO.0000103.sulfate.assimilation.sulfate.assimilation, GO.0000104.succinate.dehydrogenase.activity.succinate.dehy ...
# 2021-02-02 17:41:35 INFO::Running selected normalization method: CLR
# 2021-02-02 17:41:35 INFO::Total filtered features with variance filtering: 0
# 2021-02-02 17:41:35 INFO::Filtered feature names from variance filtering:
# 2021-02-02 17:41:35 INFO::Applying z-score to standardize continuous metadata
# 2021-02-02 17:41:35 INFO::Running selected transform method: NONE
# 2021-02-02 17:41:35 INFO::Running selected analysis method: LM
# 2021-02-02 17:41:35 INFO::Creating cluster of 48 R processes
# 2021-02-02 17:42:23 INFO::Counting total values for each feature
# 2021-02-02 17:42:23 WARNING::Deleting existing residuals file: ./results/terms_vs_case_comp_norm/residuals.rds
# 2021-02-02 17:42:23 INFO::Writing residuals to file ./results/terms_vs_case_comp_norm/residuals.rds
# 2021-02-02 17:42:23 INFO::Writing all results to file (ordered by increasing q-values): ./results/terms_vs_case_comp_norm/all_results.tsv
# 2021-02-02 17:42:23 INFO::Writing the significant results (those which are less than or equal to the threshold of 0.050000 ) to file (ordered by increasing q-values): ./results/terms_vs_case_comp_norm/significant_results.tsv
# 2021-02-02 17:42:23 INFO::Writing heatmap of significant results to file: ./results/terms_vs_case_comp_norm/heatmap.pdf
# 2021-02-02 17:42:26 INFO::Writing association plots (one for each significant association) to output folder: ./results/terms_vs_case_comp_norm
# 2021-02-02 17:42:26 INFO::Plotting associations from most to least significant, grouped by metadata
# 2021-02-02 17:42:26 INFO::Plotting data for metadata number 1, case
# 2021-02-02 17:42:26 INFO::Creating boxplot for categorical data, case vs GO.0009987.cellular.process.cellular.process
# 2021-02-02 17:42:26 INFO::Creating boxplot for categorical data, case vs GO.0019054.modulation.by.virus.of.host.cellular.process.modulation.by.virus.of.host.cellular.process
# 2021-02-02 17:42:26 INFO::Creating boxplot for categorical data, case vs GO.0044068.modulation.by.symbiont.of.host.cellular.process.modulation.by.symbiont.of.host.cellular.process
# 2021-02-02 17:42:26 INFO::Creating boxplot for categorical data, case vs GO.0008152.metabolic.process.metabolic.process
# 2021-02-02 17:42:26 INFO::Creating boxplot for categorical data, case vs GO.0019048.modulation.by.virus.of.host.process.modulation.by.virus.of.host.process
# 2021-02-02 17:42:27 INFO::Creating boxplot for categorical data, case vs GO.0071704.organic.substance.metabolic.process.organic.substance.metabolic.process
# 2021-02-02 17:42:27 INFO::Creating boxplot for categorical data, case vs GO.0035821.modulation.of.process.of.other.organism.modulation.of.process.of.other.organism
# 2021-02-02 17:42:27 INFO::Creating boxplot for categorical data, case vs GO.0044003.modulation.by.symbiont.of.host.process.modulation.by.symbiont.of.host.process
# 2021-02-02 17:42:27 INFO::Creating boxplot for categorical data, case vs GO.0044260.cellular.macromolecule.metabolic.process.cellular.macromolecule.metabolic.process
# 2021-02-02 17:42:27 INFO::Creating boxplot for categorical data, case vs GO.0051817.modulation.of.process.of.other.organism.involved.in.symbiotic.interaction.modulation.of.process.of.other.organism.involved.in.symbiotic.interaction
# 2021-02-02 17:42:27 INFO::Creating boxplot for categorical data, case vs GO.0044237.cellular.metabolic.process.cellular.metabolic.process
# 2021-02-02 17:42:27 INFO::Creating boxplot for categorical data, case vs GO.0051701.interaction.with.host.interaction.with.host
# 2021-02-02 17:42:27 INFO::Creating boxplot for categorical data, case vs GO.0044238.primary.metabolic.process.primary.metabolic.process
# 2021-02-02 17:42:28 INFO::Creating boxplot for categorical data, case vs GO.0016032.viral.process.viral.process
# 2021-02-02 17:42:28 INFO::Creating boxplot for categorical data, case vs GO.0009987.cellular.process.cellular.process
# 2021-02-02 17:42:28 INFO::Creating boxplot for categorical data, case vs GO.0044403.symbiotic.process.symbiotic.process
# 2021-02-02 17:42:28 INFO::Creating boxplot for categorical data, case vs GO.0044419.interspecies.interaction.between.organisms.interspecies.interaction.between.organisms
# 2021-02-02 17:42:28 INFO::Creating boxplot for categorical data, case vs GO.0016787.hydrolase.activity.hydrolase.activity
# 2021-02-02 17:42:28 INFO::Creating boxplot for categorical data, case vs GO.0016787.hydrolase.activity.hydrolase.activity
# 2021-02-02 17:42:28 INFO::Creating boxplot for categorical data, case vs GO.0016740.transferase.activity.transferase.activity
# 2021-02-02 17:42:28 INFO::Creating boxplot for categorical data, case vs GO.0043170.macromolecule.metabolic.process.macromolecule.metabolic.process
# 2021-02-02 17:42:29 INFO::Creating boxplot for categorical data, case vs GO.0019054.modulation.by.virus.of.host.cellular.process.modulation.by.virus.of.host.cellular.process
# 2021-02-02 17:42:29 INFO::Creating boxplot for categorical data, case vs GO.0044068.modulation.by.symbiont.of.host.cellular.process.modulation.by.symbiont.of.host.cellular.process
# 2021-02-02 17:42:29 INFO::Creating boxplot for categorical data, case vs GO.0006807.nitrogen.compound.metabolic.process.nitrogen.compound.metabolic.process
# 2021-02-02 17:42:29 INFO::Creating boxplot for categorical data, case vs GO.1901564.organonitrogen.compound.metabolic.process.organonitrogen.compound.metabolic.process
# 2021-02-02 17:42:29 INFO::Creating boxplot for categorical data, case vs GO.0044260.cellular.macromolecule.metabolic.process.cellular.macromolecule.metabolic.process
# 2021-02-02 17:42:29 INFO::Creating boxplot for categorical data, case vs GO.0016740.transferase.activity.transferase.activity
# 2021-02-02 17:42:29 INFO::Creating boxplot for categorical data, case vs GO.0005488.binding.binding
# 2021-02-02 17:42:30 INFO::Creating boxplot for categorical data, case vs GO.0009058.biosynthetic.process.biosynthetic.process
# 2021-02-02 17:42:30 INFO::Creating boxplot for categorical data, case vs GO.0019048.modulation.by.virus.of.host.process.modulation.by.virus.of.host.process
# 2021-02-02 17:42:30 INFO::Creating boxplot for categorical data, case vs GO.0044237.cellular.metabolic.process.cellular.metabolic.process
# 2021-02-02 17:42:30 INFO::Creating boxplot for categorical data, case vs GO.0050789.regulation.of.biological.process.regulation.of.biological.process
# 2021-02-02 17:42:30 INFO::Creating boxplot for categorical data, case vs GO.0016772.transferase.activity..transferring.phosphorus.containing.groups.transferase.activity..transferring.phosphorus.containing.groups
# 2021-02-02 17:42:30 INFO::Creating boxplot for categorical data, case vs GO.0034641.cellular.nitrogen.compound.metabolic.process.cellular.nitrogen.compound.metabolic.process
# 2021-02-02 17:42:30 INFO::Creating boxplot for categorical data, case vs GO.0008152.metabolic.process.metabolic.process
# 2021-02-02 17:42:30 INFO::Creating boxplot for categorical data, case vs GO.0044249.cellular.biosynthetic.process.cellular.biosynthetic.process
# 2021-02-02 17:42:31 INFO::Creating boxplot for categorical data, case vs GO.1901576.organic.substance.biosynthetic.process.organic.substance.biosynthetic.process
# 2021-02-02 17:42:31 INFO::Creating boxplot for categorical data, case vs GO.0035821.modulation.of.process.of.other.organism.modulation.of.process.of.other.organism
# 2021-02-02 17:42:31 INFO::Creating boxplot for categorical data, case vs GO.0044003.modulation.by.symbiont.of.host.process.modulation.by.symbiont.of.host.process
# 2021-02-02 17:42:31 INFO::Creating boxplot for categorical data, case vs GO.0051817.modulation.of.process.of.other.organism.involved.in.symbiotic.interaction.modulation.of.process.of.other.organism.involved.in.symbiotic.interaction
# 2021-02-02 17:42:31 INFO::Creating boxplot for categorical data, case vs GO.0050794.regulation.of.cellular.process.regulation.of.cellular.process
# 2021-02-02 17:42:31 INFO::Creating boxplot for categorical data, case vs GO.0009058.biosynthetic.process.biosynthetic.process
# 2021-02-02 17:42:31 INFO::Creating boxplot for categorical data, case vs GO.0016779.nucleotidyltransferase.activity.nucleotidyltransferase.activity
# 2021-02-02 17:42:31 INFO::Creating boxplot for categorical data, case vs GO.0071704.organic.substance.metabolic.process.organic.substance.metabolic.process
# 2021-02-02 17:42:32 INFO::Creating boxplot for categorical data, case vs GO.0065007.biological.regulation.biological.regulation
# 2021-02-02 17:42:32 INFO::Creating boxplot for categorical data, case vs GO.1901360.organic.cyclic.compound.metabolic.process.organic.cyclic.compound.metabolic.process
# 2021-02-02 17:42:32 INFO::Creating boxplot for categorical data, case vs GO.0003824.catalytic.activity.catalytic.activity
# 2021-02-02 17:42:32 INFO::Creating boxplot for categorical data, case vs GO.0043167.ion.binding.ion.binding
# 2021-02-02 17:42:32 INFO::Creating boxplot for categorical data, case vs GO.0016772.transferase.activity..transferring.phosphorus.containing.groups.transferase.activity..transferring.phosphorus.containing.groups
# 2021-02-02 17:42:32 INFO::Creating boxplot for categorical data, case vs GO.1901564.organonitrogen.compound.metabolic.process.organonitrogen.compound.metabolic.process
# 2021-02-02 17:42:32 INFO::Creating boxplot for categorical data, case vs GO.0046483.heterocycle.metabolic.process.heterocycle.metabolic.process
# plot without title

# %% [markdown]
# ## MaAsLin2 outcome analyisis (subsampled)

# %%
term_pseq_outcome<-subset_samples(physeq = term_pseq_no_neg,outcome!="NA")
x<-sample_sums(term_pseq_outcome)
y<-as_tibble(x,,rownames="sample")%>%arrange(value)
meta<-as_tibble(meta(term_pseq_outcome),rownames="sample")

# %%
y<-full_join(y,meta)
library(ggpubr)
gghistogram(data = y,x = "value",y = "..count..",color = "publication",fill = "outcome",bins = 50)+xscale("log10")
# library(mosaic)
 favstats(data = y,x = y$value)

# %%
meta<-meta(term_pseq_outcome)
meta$outcome<-gsub("Stabilized","Survived",meta$outcome)
meta$outcome<-gsub("Recovered","Survived",meta$outcome)
sample_data(term_pseq_outcome)<-sample_data(meta)

# %%
term_pseq_outcome_core<-prune_taxa(taxa_sums(term_pseq_outcome)>10,term_pseq_outcome)
term_pseq_outcome
term_pseq_outcome_core
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 13534 taxa and 25 samples ]
# sample_data() Sample Data:       [ 25 samples by 71 sample variables ]
# tax_table()   Taxonomy Table:    [ 13534 taxa by 3 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9155 taxa and 25 samples ]
# sample_data() Sample Data:       [ 25 samples by 71 sample variables ]
# tax_table()   Taxonomy Table:    [ 9155 taxa by 3 taxonomic ranks ]

# %%
term_pseq_outcome_comp<-microbiome::transform(x = term_pseq_outcome_core,transform = "compositional")

# %%
#term_pseq_outcome_core<-core(x = term_pseq_outcome_comp,detection = 1/1000,prevalence = 10/100)

# %%
COVID19_df_input_data<-data.frame(t(otu_table(term_pseq_outcome_comp)))
COVID19_df_input_metadata<-data.frame(sample_data(term_pseq_outcome_comp))

# %%
range(taxa_sums(term_pseq_outcome_core))
range(taxa_sums(term_pseq_outcome_comp))
# Out:
# [1]        11 835846410
# [1] 1.260153e-09 9.058077e-01

# %%
subset_outcome<-Maaslin2(
  input_data = COVID19_df_input_data,
  input_metadata = COVID19_df_input_metadata,
  output="./results/subset_outcome",
  min_abundance = 0, 
  min_prevalence = 0.1,  #test only features with at least 10% non-zero values. min 2.5samples to be run
  normalization = "CLR",
  transform = "NONE",
  analysis_method = "CPLM",
  max_significance = 0.05,
  random_effects = c('reads','publication'),
  fixed_effects = c("outcome"),
  correction="BH",
  standardize = TRUE,
  cores = 48,
  plot_heatmap = TRUE,
  plot_scatter = TRUE,
  heatmap_first_n =num)
#  reference="outcome,Deceased")
# Out:
# [1] "Warning: Deleting existing log file: ./results/subset_outcome/maaslin2.log"
# 2021-02-09 19:43:39 INFO::Writing function arguments to log file
# 2021-02-09 19:43:39 INFO::Verifying options selected are valid
# 2021-02-09 19:43:39 INFO::Determining format of input files
# 2021-02-09 19:43:39 INFO::Input format is data samples as rows and metadata samples as rows
# 2021-02-09 19:43:39 INFO::Formula for random effects: expr ~ (1 | reads) + (1 | publication)
# 2021-02-09 19:43:39 INFO::Formula for fixed effects: expr ~  outcome
# 2021-02-09 19:43:39 INFO::Filter data based on min abundance and min prevalence
# 2021-02-09 19:43:39 INFO::Total samples in data: 25
# 2021-02-09 19:43:39 INFO::Min samples required with min abundance for a feature not to be filtered: 2.500000
# 2021-02-09 19:43:40 INFO::Total filtered features: 651
# 2021-02-09 19:43:40 INFO::Filtered feature names from abundance and prevalence filtering: GO.0000026.alpha.1.2.mannosyltransferase.activity.alpha.1.2.mannosyltransferase.activity, GO.0000052.citrulline.metabolic.process.citrulline.metabolic.process, GO.0000140.acylglycerone.phosphate.reductase.activity.acylglycerone.phosphate.reductase.activity, GO.0000147.actin.cortical.patch.assembly.actin.cortical.patch.assembly, GO.0000183.rDNA.heterochromatin.assembly.rDNA.heterochromatin.assembly, GO.0000266.mitochondrial.fission.mitochondrial.fission, GO.0000293.ferric.chelate.reductase.activity.ferric.chelate.reductase.activity, GO.0000436.carbon.catabolite.activation.of.transcription.from.RNA.polymerase.II.promoter.carbon.catabolite.activation.of.transcription.from.RNA.polymerase.II.promoter, GO.0000773.phosphatidyl.N.methylethanolamine.N.methyltransferase.activity.phosphatidyl.N.methylethanolamine.N.methyltransferase.activity, GO.0000957.mitochondrial.RNA.catabolic.process.mitochondrial.RNA.catabolic.process, GO.0000958.mitochondrial.mRNA.catabolic.process.mitochondrial.mRNA.catabolic.process, GO.0000972.transcription.dependent.tethering.of.RNA.polymerase.II.gene.DNA.at.nuclear.periphery.transcription.dependent.tethering.of.RNA.polymerase.II.gene.DNA.at.nuclear.periphery, GO.0000973.posttranscriptional.tethering.of.RNA.polymerase.II.gene.DNA.at.nuclear.periphery.posttranscriptional.tethering.of.RNA.polymerase.II.gene.DNA.at.nuclear.periphery, GO.0001017.bacterial.type.RNA.polymerase.transcription.regulatory.region.sequence.specific.DNA.binding.bacterial.type.RNA.polymerase.transcription.regulatory.region.sequence.specific.DNA.binding, GO.0001047.core.promoter.sequence.specific.DNA.binding.core.promoter.sequence.specific.DNA.binding, GO.0001070.RNA.binding.transcription.regulator.activity.RNA.binding.transcription.regulator.activity, GO.0001075.RNA.polymerase.II.general.transcription.initiation.factor.activity.RNA.polymerase.II.general.transcription.initiation.factor.activity, GO.0001085.RNA.polymerase.II.transcription.factor.binding.RNA.polymerase.II.transcription.factor.binding, GO.0001091.RNA.polymerase.II.general.transcription.initiation.factor.binding.RNA.polymerase.II.general.transcription.initiation.factor.binding, GO.0001095.TFIIE.class.transcription.factor.complex.binding.TFIIE.class.transcription.factor.complex.binding, GO.0001097.TFIIH.class.transcription.factor.complex.binding.TFIIH.class.transcription.factor.complex.binding, GO.0001099.basal.RNA.polymerase.II.transcription.machinery.binding.basal.RNA.polymerase.II.transcription.machinery.binding, GO.0001163.RNA.polymerase.I.transcription.regulatory.region.sequence.specific.DNA.binding.RNA.polymerase.I.transcription.regulatory.region.sequence.specific.DNA.binding, GO.0001165.RNA.polymerase.I.cis.regulatory.region.sequence.specific.DNA.binding.RNA.polymerase.I.cis.regulatory.region.sequence.specific.DNA.binding, GO.0001181.RNA.polymerase.I.general.transcription.initiation.factor.activity.RNA.polymerase.I.general.transcription.initiation.factor.activity, GO.0001223.transcription.coactivator.binding.transcription.coactivator.binding, GO.0001540.amyloid.beta.binding.amyloid.beta.binding, GO.0001561.fatty.acid.alpha.oxidation.fatty.acid.alpha.oxidation, GO.0001570.vasculogenesis.vasculogenesis, GO.0001657.ureteric.bud.development.ureteric.bud.development, GO.0001731.formation.of.translation.preinitiation.complex.formation.of.translation.preinitiation.complex, GO.0001732.formation.of.cytoplasmic.translation.initiation.complex.formation.of.cytoplasmic.translation.initiation.complex, GO.0001765.membrane.raft.assembly.membrane.raft.assembly, GO.0001875.lipopolysaccharide.immune.receptor.activity.lipopolysaccharide.immune.receptor.activity, GO.0002083.4.hydroxybenzoate.decaprenyltransferase.activity.4.hydroxybenzoate.decaprenyltransferase.activity, GO.0002184.cytoplasmic.translational.termination.cytoplasmic.translational.termination, GO.0002188.translation.reinitiation.translation. ...
# 2021-02-09 19:43:40 INFO::Running selected normalization method: CLR
# 2021-02-09 19:43:40 INFO::Total filtered features with variance filtering: 0
# 2021-02-09 19:43:40 INFO::Filtered feature names from variance filtering:
# 2021-02-09 19:43:40 INFO::Applying z-score to standardize continuous metadata
# 2021-02-09 19:43:40 INFO::Running selected transform method: NONE
# 2021-02-09 19:43:40 INFO::Running selected analysis method: CPLM
# 2021-02-09 19:43:40 INFO::Creating cluster of 48 R processes
# 2021-02-09 19:53:27 INFO::Counting total values for each feature
# 2021-02-09 19:53:28 WARNING::Deleting existing residuals file: ./results/subset_outcome/residuals.rds
# 2021-02-09 19:53:28 INFO::Writing residuals to file ./results/subset_outcome/residuals.rds
# 2021-02-09 19:53:28 INFO::Writing all results to file (ordered by increasing q-values): ./results/subset_outcome/all_results.tsv
# 2021-02-09 19:53:29 INFO::Writing the significant results (those which are less than or equal to the threshold of 0.050000 ) to file (ordered by increasing q-values): ./results/subset_outcome/significant_results.tsv
# 2021-02-09 19:53:29 INFO::Writing heatmap of significant results to file: ./results/subset_outcome/heatmap.pdf
# [1] "There is not enough metadata in the associations to create a heatmap plot. Please review the associations in text output file."
# 2021-02-09 19:53:29 INFO::Writing association plots (one for each significant association) to output folder: ./results/subset_outcome
# 2021-02-09 19:53:29 INFO::Plotting associations from most to least significant, grouped by metadata
# 2021-02-09 19:53:29 INFO::Plotting data for metadata number 1, outcome
# 2021-02-09 19:53:29 INFO::Creating boxplot for categorical data, outcome vs GO.0006220.pyrimidine.nucleotide.metabolic.process.pyrimidine.nucleotide.metabolic.process
# 2021-02-09 19:53:29 INFO::Creating boxplot for categorical data, outcome vs GO.0034404.nucleobase.containing.small.molecule.biosynthetic.process.nucleobase.containing.small.molecule.biosynthetic.process
# 2021-02-09 19:53:29 INFO::Creating boxplot for categorical data, outcome vs GO.0034655.nucleobase.containing.compound.catabolic.process.nucleobase.containing.compound.catabolic.process
# 2021-02-09 19:53:29 INFO::Creating boxplot for categorical data, outcome vs GO.0009141.nucleoside.triphosphate.metabolic.process.nucleoside.triphosphate.metabolic.process
# 2021-02-09 19:53:29 INFO::Creating boxplot for categorical data, outcome vs GO.0034654.nucleobase.containing.compound.biosynthetic.process.nucleobase.containing.compound.biosynthetic.process
# 2021-02-09 19:53:29 INFO::Creating boxplot for categorical data, outcome vs GO.0006221.pyrimidine.nucleotide.biosynthetic.process.pyrimidine.nucleotide.biosynthetic.process
# 2021-02-09 19:53:29 INFO::Creating boxplot for categorical data, outcome vs GO.0046914.transition.metal.ion.binding.transition.metal.ion.binding
# 2021-02-09 19:53:29 INFO::Creating boxplot for categorical data, outcome vs GO.0034061.DNA.polymerase.activity.DNA.polymerase.activity
# 2021-02-09 19:53:30 INFO::Creating boxplot for categorical data, outcome vs GO.0072527.pyrimidine.containing.compound.metabolic.process.pyrimidine.containing.compound.metabolic.process
# 2021-02-09 19:53:30 INFO::Creating boxplot for categorical data, outcome vs GO.0006950.response.to.stress.response.to.stress
# 2021-02-09 19:53:30 INFO::Creating boxplot for categorical data, outcome vs GO.0015074.DNA.integration.DNA.integration
# 2021-02-09 19:53:30 INFO::Creating boxplot for categorical data, outcome vs GO.0009124.nucleoside.monophosphate.biosynthetic.process.nucleoside.monophosphate.biosynthetic.process
# 2021-02-09 19:53:30 INFO::Creating boxplot for categorical data, outcome vs GO.0006281.DNA.repair.DNA.repair
# 2021-02-09 19:53:30 INFO::Creating boxplot for categorical data, outcome vs GO.0046700.heterocycle.catabolic.process.heterocycle.catabolic.process
# 2021-02-09 19:53:30 INFO::Creating boxplot for categorical data, outcome vs GO.0043604.amide.biosynthetic.process.amide.biosynthetic.process
# 2021-02-09 19:53:30 INFO::Creating boxplot for categorical data, outcome vs GO.0004175.endopeptidase.activity.endopeptidase.activity
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.0008270.zinc.ion.binding.zinc.ion.binding
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.0016655.oxidoreductase.activity..acting.on.NAD.P.H..quinone.or.similar.compound.as.acceptor.oxidoreductase.activity..acting.on.NAD.P.H..quinone.or.similar.compound.as.acceptor
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.0072528.pyrimidine.containing.compound.biosynthetic.process.pyrimidine.containing.compound.biosynthetic.process
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.1901361.organic.cyclic.compound.catabolic.process.organic.cyclic.compound.catabolic.process
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.0016070.RNA.metabolic.process.RNA.metabolic.process
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.0019438.aromatic.compound.biosynthetic.process.aromatic.compound.biosynthetic.process
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.0006974.cellular.response.to.DNA.damage.stimulus.cellular.response.to.DNA.damage.stimulus
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.0052126.movement.in.host.environment.movement.in.host.environment
# 2021-02-09 19:53:31 INFO::Creating boxplot for categorical data, outcome vs GO.0044409.entry.into.host.entry.into.host
# 2021-02-09 19:53:32 INFO::Creating boxplot for categorical data, outcome vs GO.0046718.viral.entry.into.host.cell.viral.entry.into.host.cell
# 2021-02-09 19:53:32 INFO::Creating boxplot for categorical data, outcome vs GO.0016773.phosphotransferase.activity..alcohol.group.as.acceptor.phosphotransferase.activity..alcohol.group.as.acceptor
# 2021-02-09 19:53:32 INFO::Creating boxplot for categorical data, outcome vs GO.1901362.organic.cyclic.compound.biosynthetic.process.organic.cyclic.compound.biosynthetic.process
# 2021-02-09 19:53:32 INFO::Creating boxplot for categorical data, outcome vs GO.0009059.macromolecule.biosynthetic.process.macromolecule.biosynthetic.process
# 2021-02-09 19:53:32 INFO::Creating boxplot for categorical data, outcome vs GO.0016874.ligase.activity.ligase.activity
# 2021-02-09 19:53:32 INFO::Creating boxplot for categorical data, outcome vs GO.0032555.purine.ribonucleotide.binding.purine.ribonucleotide.binding
# 2021-02-09 19:53:32 INFO::Creating boxplot for categorical data, outcome vs GO.0033554.cellular.response.to.stress.cellular.response.to.stress
# 2021-02-09 19:53:32 INFO::Creating boxplot for categorical data, outcome vs GO.0090501.RNA.phosphodiester.bond.hydrolysis.RNA.phosphodiester.bond.hydrolysis
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.0016301.kinase.activity.kinase.activity
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.0016310.phosphorylation.phosphorylation
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.0051716.cellular.response.to.stimulus.cellular.response.to.stimulus
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.0017076.purine.nucleotide.binding.purine.nucleotide.binding
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.0035639.purine.ribonucleoside.triphosphate.binding.purine.ribonucleoside.triphosphate.binding
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.0016491.oxidoreductase.activity.oxidoreductase.activity
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.0055114.oxidation.reduction.process.oxidation.reduction.process
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.0016746.transferase.activity..transferring.acyl.groups.transferase.activity..transferring.acyl.groups
# 2021-02-09 19:53:33 INFO::Creating boxplot for categorical data, outcome vs GO.1901565.organonitrogen.compound.catabolic.process.organonitrogen.compound.catabolic.process
# 2021-02-09 19:53:34 INFO::Creating boxplot for categorical data, outcome vs GO.0043603.cellular.amide.metabolic.process.cellular.amide.metabolic.process
# 2021-02-09 19:53:34 INFO::Creating boxplot for categorical data, outcome vs GO.0006812.cation.transport.cation.transport
# 2021-02-09 19:53:34 INFO::Creating boxplot for categorical data, outcome vs GO.0000287.magnesium.ion.binding.magnesium.ion.binding
# 2021-02-09 19:53:34 INFO::Creating boxplot for categorical data, outcome vs GO.0140098.catalytic.activity..acting.on.RNA.catalytic.activity..acting.on.RNA
# 2021-02-09 19:53:34 INFO::Creating boxplot for categorical data, outcome vs GO.0003723.RNA.binding.RNA.binding
# 2021-02-09 19:53:34 INFO::Creating boxplot for categorical data, outcome vs GO.1901363.heterocyclic.compound.binding.heterocyclic.compound.binding
# 2021-02-09 19:53:34 INFO::Creating boxplot for categorical data, outcome vs GO.0005975.carbohydrate.metabolic.process.carbohydrate.metabolic.process
# 2021-02-09 19:53:34 INFO::Creating boxplot for categorical data, outcome vs GO.0071840.cellular.component.organization.or.biogenesis.cellular.component.organization.or.biogenesis
# 2021-02-09 19:53:35 INFO::Creating boxplot for categorical data, outcome vs GO.0016818.hydrolase.activity..acting.on.acid.anhydrides..in.phosphorus.containing.anhydrides.hydrolase.activity..acting.on.acid.anhydrides..in.phosphorus.containing.anhydrides
# 2021-02-09 19:53:35 INFO::Creating boxplot for categorical data, outcome vs GO.0006355.regulation.of.transcription..DNA.templated.regulation.of.transcription..DNA.templated
# 2021-02-09 19:53:35 INFO::Creating boxplot for categorical data, outcome vs GO.1903506.regulation.of.nucleic.acid.templated.transcription.regulation.of.nucleic.acid.templated.transcription

# %% [markdown]
# #### run another model using only the COVID19 samples and identify GO Terms associated with deceased

# %%
res<-case_norm$results%>%filter(pval<=0.05)
subset_outcome_res<-subset_outcome$results%>%filter(pval<=0.01)

# %%
subset_outcome_res
# Out:
#    feature
# 1  GO.0004252.serine.type.endopeptidase.activity.serine.type.endopeptidase.activity
# 2  GO.0090501.RNA.phosphodiester.bond.hydrolysis.RNA.phosphodiester.bond.hydrolysis
# 3  GO.0003723.RNA.binding.RNA.binding
# 4  GO.0004540.ribonuclease.activity.ribonuclease.activity
# 5  GO.0005198.structural.molecule.activity.structural.molecule.activity
# 6  GO.0008270.zinc.ion.binding.zinc.ion.binding
# 7  GO.0016070.RNA.metabolic.process.RNA.metabolic.process
# 8  GO.0017111.nucleoside.triphosphatase.activity.nucleoside.triphosphatase.activity
# 9  GO.0031324.negative.regulation.of.cellular.metabolic.process.negative.regulation.of.cellular.metabolic.process
# 10 GO.0034654.nucleobase.containing.compound.biosynthetic.process.nucleobase.containing.compound.biosynthetic.process
# 11 GO.0034654.nucleobase.containing.compound.biosynthetic.process.nucleobase.containing.compound.biosynthetic.process
# 12 GO.0044409.entry.into.host.entry.into.host
# 13 GO.0046718.viral.entry.into.host.cell.viral.entry.into.host.cell
# 14 GO.0046914.transition.metal.ion.binding.transition.metal.ion.binding
# 15 GO.0052126.movement.in.host.environment.movement.in.host.environment
# 16 GO.0070180.large.ribosomal.subunit.rRNA.binding.large.ribosomal.subunit.rRNA.binding
# 17 GO.0090501.RNA.phosphodiester.bond.hydrolysis.RNA.phosphodiester.bond.hydrolysis
# 18 GO.0090503.RNA.phosphodiester.bond.hydrolysis..exonucleolytic.RNA.phosphodiester.bond.hydrolysis..exonucleolytic
#    metadata value      coef          stderr       pval
# 1  outcome  Stabilized  0.0003215228 8.311513e-05 0.0001843246
# 2  outcome  Stabilized -0.0019786994 4.110214e-04 0.0001899241
# 3  outcome  Recovered   0.0015167408 4.593866e-04 0.0046539461
# 4  outcome  Recovered  -0.0018753961 6.350595e-04 0.0093622084
# 5  outcome  Recovered   0.0008070809 2.732621e-04 0.0093265950
# 6  outcome  Recovered  -0.0008017119 2.510016e-04 0.0057519093
# 7  outcome  Recovered  -0.0013540964 4.515172e-04 0.0087681337
# 8  outcome  Stabilized  0.0007775572 2.084900e-04 0.0017829308
# 9  outcome  Stabilized  0.0001955420 6.085996e-05 0.0013257577
# 10 outcome  Stabilized -0.0016654950 4.913894e-04 0.0037190343
# 11 outcome  Recovered  -0.0016797463 5.506519e-04 0.0076087126
# 12 outcome  Stabilized -0.0007464447 2.369029e-04 0.0061700495
# 13 outcome  Stabilized -0.0007464700 2.369052e-04 0.0061690706
# 14 outcome  Recovered  -0.0006401064 1.839061e-04 0.0055622912
# 15 outcome  Stabilized -0.0007333804 2.379194e-04 0.0071212389
# 16 outcome  Recovered   0.0000689149 2.581343e-05 0.0080772977
# 17 outcome  Recovered  -0.0014850947 4.607215e-04 0.0053059442
# 18 outcome  Recovered  -0.0009817161 3.317137e-04 0.0092614661
#    name              qval      N  N.not.zero
# 1  outcomeStabilized 0.1992304 25  0
# 2  outcomeStabilized 0.1992304 25 15
# 3  outcomeRecovered  0.3908745 25 23
# 4  outcomeRecovered  0.3908745 25 17
# 5  outcomeRecovered  0.3908745 25  2
# 6  outcomeRecovered  0.3908745 25 17
# 7  outcomeRecovered  0.3908745 25 25
# 8  outcomeStabilized 0.3908745 25 23
# 9  outcomeStabilized 0.3908745 25  0
# 10 outcomeStabilized 0.3908745 25 25
# 11 outcomeRecovered  0.3908745 25 25
# 12 outcomeStabilized 0.3908745 25  4
# 13 outcomeStabilized 0.3908745 25  4
# 14 outcomeRecovered  0.3908745 25 23
# 15 outcomeStabilized 0.3908745 25  4
# 16 outcomeRecovered  0.3908745 25  0
# 17 outcomeRecovered  0.3908745 25 15
# 18 outcomeRecovered  0.3908745 25 15

# %%
subset_outcome_res<-subset_outcome$results%>%filter(pval<=0.05)
dim(subset_outcome_res)
# Out:
# [1] 244  10

# %%
Terms<-gsub("GO.","GO:",res$feature)
Terms<-gsub("[.]"," ",Terms)
Terms<-sub(" ","-",Terms)
Terms<-as_tibble(Terms)
Terms<-separate(data = Terms,col = value,sep = "-",into =  c("Term", "name"))

# %%
term_pseq_prune <- prune_taxa(taxa = Terms$Term,x =term_pseq_no_neg_gonames)
term_pseq_prune #[85 taxa and 141 samples ]
tax<-data.frame(tax_table(term_pseq_prune))
names<-paste(rownames(tax),tax$name,sep="-")
taxa_names(term_pseq_prune)<-names
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 35 taxa and 86 samples ]
# sample_data() Sample Data:       [ 86 samples by 72 sample variables ]
# tax_table()   Taxonomy Table:    [ 35 taxa by 3 taxonomic ranks ]

# %%
save.image("./images/2_maaslin2.rda")
