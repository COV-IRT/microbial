# %% [markdown]
# # Visualisations
# ###  COVIRT19 microbial subgroup seqscreen analysis
# #### Date : 21 DEC 2020
# #### Maintained by :
#     Jochum, Michael D.
#     Baylor College of Medicine
#     michael.jochum@bcm.edu

# %% [markdown]
# #### Mike, thatnk for walking me through this pheatmap stuff I actually found a couple bugs in the code that made it through.
# - Remember how you were asking why the dmm cluster annotations on the left hand side of the map werent identical?  It was because I never subsetted the annotation row to match the terms, and I think it was just

# %%
library(phyloseq)
library(microbiome)
library(tidyverse)
library(dplyr)
library(tidyr)
library(scales)
library(RColorBrewer)
library(ggsci)
library(viridis)
library(pheatmap)
library(MatrixGenerics)
library(FactoMineR)
library(factoextra)

# %%
setwd("/media/jochum00/Aagaard_Raid3/jupyter_notebooks/jochum00_jupyter/microbial/GO_term_analysis/16_DEC_2020_dmm_troubleshooting_Lee/")
getwd()
# Out:
# [1] "/media/jochum00/Aagaard_Raid3/jupyter_notebooks/jochum00_jupyter/microbial/GO_term_analysis/16_DEC_2020_dmm_troubleshooting_Lee"

# %%
load(file = "./images/2_maaslin2.rda")

# %%
term_pseq_prune_comp2<-microbiome::transform(transform = "compositional",term_pseq_no_neg_gonames)
term_pseq_prune_comp<-microbiome::transform(transform = "compositional",term_pseq_prune)
term_pseq_prune_comp
term_pseq_prune_comp2
#term_pseq_prune <- prune_taxa(taxa = Terms$Term,x =term_pseq_prune_comp)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 35 taxa and 86 samples ]
# sample_data() Sample Data:       [ 86 samples by 72 sample variables ]
# tax_table()   Taxonomy Table:    [ 35 taxa by 3 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 13534 taxa and 86 samples ]
# sample_data() Sample Data:       [ 86 samples by 72 sample variables ]
# tax_table()   Taxonomy Table:    [ 13534 taxa by 3 taxonomic ranks ]

# %%
term_pseq_prune_comp2 <- prune_taxa(taxa = Terms$Term,x =term_pseq_prune_comp2)
term_pseq_prune_comp2
tax<-data.frame(tax_table(term_pseq_prune_comp2))
names<-paste(rownames(tax),tax$name,sep="-")
taxa_names(term_pseq_prune_comp2)<-names
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 35 taxa and 86 samples ]
# sample_data() Sample Data:       [ 86 samples by 72 sample variables ]
# tax_table()   Taxonomy Table:    [ 35 taxa by 3 taxonomic ranks ]

# %%
sam2<-as_tibble(sample_data(term_pseq_prune_comp2))
sam<-as_tibble(sample_data(term_pseq_prune_comp))
library(mosaic)
# Out:
# Warning message in class(x) <- c(setdiff(subclass, tibble_class), tibble_class):
# “Setting class(x) to multiple strings ("tbl_df", "tbl", ...); result will no longer be an S4 object”
# Warning message in class(x) <- c(setdiff(subclass, tibble_class), tibble_class):
# “Setting class(x) to multiple strings ("tbl_df", "tbl", ...); result will no longer be an S4 object”

# %%
count<-abundances(term_pseq_prune_comp)
select <- order(rowMeans(count),decreasing=TRUE)
select3<-order(rowSdDiffs(count),decreasing=T)
select2<-(count)[select,]
tmp<-rownames(select2)
dim(select2)
write.table(select2,file = "./results/GO_Terms_results.tsv",sep = "\t")
select2<-as_tibble(select2, rownames=NA)

countb<-abundances(term_pseq_prune_comp2)
selectb <- order(rowMeans(countb),decreasing=TRUE)
select3b<-order(rowSdDiffs(countb),decreasing=T)
select2b<-(countb)[select,]
tmpb<-rownames(select2b)
dim(select2b)
write.table(select2b,file = "./results/GO_Terms_results.tsv",sep = "\t")
select2b<-as_tibble(select2b, rownames=NA)
# Out:
# [1] 35 86
# [1] 35 86

# %%
sam<-data.frame(sample_data(term_pseq_prune_comp))
df<-as.data.frame(sample_data(term_pseq_prune_comp))
df<-as_tibble(df, rownames = NA)
df<-df%>%select(publication, dmn,case,outcome)
df<-as.data.frame(df)


sam<-data.frame(sample_data(term_pseq_prune_comp2))
dfb<-as.data.frame(sample_data(term_pseq_prune_comp2))
dfb<-as_tibble(dfb, rownames = NA)
dfb<-dfb%>%select(publication,dmn, case,outcome)
dfb<-as.data.frame(dfb)
# Out:
# Warning message in class(x) <- c(setdiff(subclass, tibble_class), tibble_class):
# “Setting class(x) to multiple strings ("tbl_df", "tbl", ...); result will no longer be an S4 object”
# Warning message in class(x) <- c(setdiff(subclass, tibble_class), tibble_class):
# “Setting class(x) to multiple strings ("tbl_df", "tbl", ...); result will no longer be an S4 object”

# %%
index<-rownames(select2)
indexb<-rownames(select2b)

# %%
colnames(select2) <- colnames(otu_table(term_pseq_prune_comp))
row.names(df) <- colnames(select2)

colnames(select2b) <- colnames(otu_table(term_pseq_prune_comp))
row.names(dfb) <- colnames(select2)

# %%
mypal <- pal_aaas("default", alpha = 1)(10)
df_row<-as.data.frame(fitted(best))
colnames(df_row)<-c("1","2","3")#,"4","5","6")
df<-data.frame(df)
colnames(df)<-c("Publication","dmm_cluster", "Case","Outcome")

mypal <- pal_aaas("default", alpha = 1)(10)
df_row<-as.data.frame(fitted(best))
colnames(df_row)<-c("1","2","3")#,"4","5","6")
dfb<-data.frame(dfb)
colnames(dfb)<-c("Publication","dmm_cluster", "Case","Outcome")

# %%
ann_colors = list(
    Publication=c("Xiong"="#008280FF", "Shen"="#631879FF","Chen"="#3B4992FF","Wu"="#EE0000FF","Zhou"="orange","Ren"="#111111"),
    dmm_cluster=c("1"="#EE0000FF","2"="#3B4992FF","3"="#008B45FF"),
    Case=c("COVID19"="firebrick","Community_acquired_pneumonia"="darkorange1", "Control_Healthy"="forestgreen"),
    Outcome=c("Deceased"="black","Stabilized"="goldenrod4","Recovered"="forestgreen"))

# %%
sub_best<-as_tibble(fitted(best),rownames = "Term")
colnames(sub_best)<-c("Term","1","2","3")

# %% [markdown]
# # why are the descriptions duplicated......

# %%
sub_best<-sub_best%>%filter(Term %in%c('GO:0003824-catalytic activity-catalytic activity',
'GO:0008152-metabolic process-metabolic process',
'GO:0009987-cellular process-cellular process',
'GO:0071704-organic substance metabolic process-organic substance metabolic process',
'GO:0044237-cellular metabolic process-cellular metabolic process',
'GO:0005488-binding-binding',
'GO:0044238-primary metabolic process-primary metabolic process',
'GO:0016787-hydrolase activity-hydrolase activity',
'GO:0006807-nitrogen compound metabolic process-nitrogen compound metabolic process',
'GO:0016740-transferase activity-transferase activity',
'GO:0043170-macromolecule metabolic process-macromolecule metabolic process',
'GO:0034641-cellular nitrogen compound metabolic process-cellular nitrogen compound metabolic process',
'GO:1901360-organic cyclic compound metabolic process-organic cyclic compound metabolic process',
'GO:0046483-heterocycle metabolic process-heterocycle metabolic process',
'GO:0044419-interspecies interaction between organisms-interspecies interaction between organisms',
'GO:0044403-symbiotic process-symbiotic process',
'GO:0009058-biosynthetic process-biosynthetic process',
'GO:0016032-viral process-viral process',
'GO:0043167-ion binding-ion binding',
'GO:0016772-transferase activity, transferring phosphorus-containing groups-transferase activity, transferring phosphorus-containing groups',
'GO:1901576-organic substance biosynthetic process-organic substance biosynthetic process',
'GO:0044249-cellular biosynthetic process-cellular biosynthetic process',
'GO:0065007-biological regulation-biological regulation',
'GO:0044260-cellular macromolecule metabolic process-cellular macromolecule metabolic process',
'GO:0050789-regulation of biological process-regulation of biological process',
'GO:1901564-organonitrogen compound metabolic process-organonitrogen compound metabolic process',
'GO:0050794-regulation of cellular process-regulation of cellular process',
'GO:0051701-interaction with host-interaction with host',
'GO:0016779-nucleotidyltransferase activity-nucleotidyltransferase activity',
'GO:0035821-modulation of process of other organism-modulation of process of other organism',
'GO:0051817-modulation of process of other organism involved in symbiotic interaction-modulation of process of other organism involved in symbiotic interaction',
'GO:0044003-modulation by symbiont of host process-modulation by symbiont of host process',
'GO:0019048-modulation by virus of host process-modulation by virus of host process',
'GO:0044068-modulation by symbiont of host cellular process-modulation by symbiont of host cellular process',
'GO:0019054-modulation by virus of host cellular process-modulation by virus of host cellular process'))

# %%
df_row<-as.data.frame(sub_best)
rownames(df_row)<-df_row$Term
df_row$Term<-NULL

# %%
df_row<-as.data.frame(fitted(best))
ann_colors
# Out:
# $Publication
#       Xiong        Shen        Chen          Wu        Zhou         Ren
# "#008280FF" "#631879FF" "#3B4992FF" "#EE0000FF"    "orange"   "#111111"
#
# $dmm_cluster
#           1           2           3
# "#EE0000FF" "#3B4992FF" "#008B45FF"
#
# $Case
#                      COVID19 Community_acquired_pneumonia
#                  "firebrick"                "darkorange1"
#              Control_Healthy
#                "forestgreen"
#
# $Outcome
#      Deceased    Stabilized     Recovered
#       "black"  "goldenrod4" "forestgreen"

# %% [markdown]
# ## heat map Ex 1:
#  - compositional transformation before and after subessting for Maaslin2 GO Terms
#  - No distance claustering
#  - No color z score scaling

# %%
options(repr.plot.width=20, repr.plot.height=8)
xx <- pheatmap(mat = select2,
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(1000),
               annotation_col=df,
               annotation_colors = ann_colors,
               cluster_row=FALSE,
               cluster_cols=FALSE,
               #clustering_distance_rows = "euclidean",
               #clustering_distance_cols = "euclidean",
              annotation_row =df_row)
options(repr.plot.width=20, repr.plot.height=8)
xx <- pheatmap(mat = select2b,
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(1000),
               annotation_col=df,
               annotation_colors = ann_colors,
               cluster_row=FALSE,
               cluster_cols=FALSE,
               #clustering_distance_rows = "euclidean",
               #clustering_distance_cols = "euclidean",
              annotation_row = df_row)
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## heat map Ex 2:
#  - compositional transformation before and after subessting for Maaslin2 GO Terms
#  - No distance claustering
#  - color z score scaling

# %%
options(repr.plot.width=20, repr.plot.height=8)
xx <- pheatmap(mat = select2,
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(1000),
               annotation_col=df,
               scale="row",
               annotation_colors = ann_colors,
               cluster_row=FALSE,cluster_cols=FALSE,
               
               #clustering_distance_rows = "euclidean",
               #clustering_distance_cols = "euclidean",
              annotation_row =df_row)
options(repr.plot.width=20, repr.plot.height=8)
xx <- pheatmap(mat = select2b,
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(1000),
               annotation_col=df,
               scale="row",
               annotation_colors = ann_colors,
               cluster_row=FALSE,cluster_cols=FALSE,
               #clustering_distance_rows = "euclidean",
               #clustering_distance_cols = "euclidean",
              annotation_row = df_row)
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## heat map Ex 3:
#  - compositional transformation before and after subessting for Maaslin2 GO Terms
#  - distance clustering
#  - No color z score scaling

# %%
options(repr.plot.width=20, repr.plot.height=8)
xx <- pheatmap(mat = select2,
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(1000),
               annotation_col=df,
               annotation_colors = ann_colors,
               clustering_distance_rows = "euclidean",
               clustering_distance_cols = "euclidean",
              annotation_row =df_row)
options(repr.plot.width=20, repr.plot.height=8)
xx <- pheatmap(mat = select2b,
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(1000),
               annotation_col=df,
               annotation_colors = ann_colors,
               clustering_distance_rows = "euclidean",
               clustering_distance_cols = "euclidean",
              annotation_row = df_row)
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## heat map Ex 4:
#  - compositional transformation before and after subsetting for Maaslin2 GO Terms
#  - Distance clustering
#  - z score scaling

# %%
options(repr.plot.width=24, repr.plot.height=8)
xx <- pheatmap(mat = select2,
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(1000),
               annotation_col=df,
                scale="row",
               annotation_colors = ann_colors,
               clustering_distance_rows = "euclidean",
               clustering_distance_cols = "euclidean",
              annotation_row =df_row)
options(repr.plot.width=24, repr.plot.height=8)
xx <- pheatmap(mat = select2b,
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(1000),
               annotation_col=df,
               scale="row",
               annotation_colors = ann_colors,
               clustering_distance_rows = "euclidean",
               clustering_distance_cols = "euclidean",
              annotation_row = df_row)
# Out:
# plot without title
# plot without title

# %% [markdown]
# # Everything below her is Original STUFF

# %%
options(repr.plot.width=24, repr.plot.height=8)
xx <- pheatmap(mat = select2,
               color =  colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(10),
               annotation_col=df,
               annotation_colors = ann_colors,
               clustering_distance_rows = "euclidean",
               clustering_distance_cols = "euclidean",
               annotation_row = df_row,
               cluster_row = T,
               cluster_col=T)
# Out:
# plot without title

# %% [markdown]
# ### Ammendment that removes the publication coloumn

# %%
# Ammendment that removes the publication coloumn
df<-df%>%select(-Publication)

# %%
ann_colors = list(
  dmm_cluster=c("1"="#EE0000FF","2"="#3B4992FF","3"="#008B45FF"),#,"4"="#631879FF"),#,"5"="#008280FF","6"="#BB0021FF","7"="#5F559BFF"),
  Publication=c("Xiong"="#008280FF", "Shen"="#631879FF","Chen"="#3B4992FF","Wu"="#EE0000FF","Zhou"="orange","Ren"="#111111"),
  Case=c("COVID19"="firebrick","Community_acquired_pneumonia"="darkorange1", "Control_Healthy"="forestgreen"),
 # Sample_Type=c("COVID_19"="firebrick","Community_acquired_pneumonia"="darkorange1", "Healthy"="forestgreen"),
Outcome=c("Deceased"="black","Stabilized"="goldenrod4","Recovered"="forestgreen"))
options(repr.plot.width=24, repr.plot.height=8)
xx <- pheatmap(mat = select2,scale="none",
               color = colorRampPalette(rev(brewer.pal(n = 10, name ="RdYlBu")))(7),
               annotation_col=df,
               annotation_colors = ann_colors,
               clustering_distance_rows = "euclidean",
               clustering_distance_cols = "euclidean",
              annotation_row = df_row)
# Out:
# plot without title

# %%
options(repr.plot.width=5, repr.plot.height=5)
b
res.CA<-CA(a,graph=F)

fviz_ca_biplot(res.CA,
               repel=T,
               col.col="cos2",
               col.row="cos2")
# Out:
#   case                         dmn n
# 1 Community_acquired_pneumonia 1   12
# 2 Control_Healthy              1   26
# 3 COVID19                      1    1
# 4 Community_acquired_pneumonia 2   11
# 5 Control_Healthy              2    2
# 6 COVID19                      2   21
# 7 Community_acquired_pneumonia 3    2
# 8 Control_Healthy              3    1
# 9 COVID19                      3   10
# Error in U[, num, drop = FALSE]: incorrect number of dimensions
# Traceback:
#
# 1. CA(a, graph = F)
# 2. svd.triplet(Tc, row.w = marge.row, col.w = marge.col, ncp = ncp)

# %%
a<-tally(~outcome,meta(term_pseq_prune))

# %%
a
# Out:
# outcome
#   Deceased  Recovered Stabilized       <NA>
#         10          7          8         61

# %%
options(repr.plot.width=8, repr.plot.height=8)
a<-tally(~outcome+dmn,meta(term_pseq_prune))
res.CA<-CA(a,graph=F)

fviz_ca_biplot(res.CA,
               repel=T,
               col.col="cos2",
               col.row="cos2")
# Out:
# plot without title

# %%
save.image("./images/3_heatmap.rda")

# %%
chisq.test(tally(case=="COVID19"~dmn, meta(term_pseq_prune)))
fisher.test(tally(case=="COVID19"~dmn, meta(term_pseq_prune)))
# Out:
# Warning message in chisq.test(tally(case == "COVID19" ~ dmn, meta(term_pseq_prune))):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tally(case == "COVID19" ~ dmn, meta(term_pseq_prune))
# X-squared = 37.586, df = 2, p-value = 6.892e-09
# 	Fisher's Exact Test for Count Data
#
# data:  tally(case == "COVID19" ~ dmn, meta(term_pseq_prune))
# p-value = 2.005e-10
# alternative hypothesis: two.sided

# %% [markdown]
# ### Chisq. test and factorial anova

# %%
chisq.test(b)
# Out:
# Error in chisq.test(b): all entries of 'x' must be nonnegative and finite
# Traceback:
#
# 1. chisq.test(b)
# 2. stop("all entries of 'x' must be nonnegative and finite")

# %%
b<-as_tibble(tally(case~dmn, meta(term_pseq_prune)))
c<-b%>%pivot_wider(names_from = case,values_from=n)
#factorial anova
c
write.table(c,"dmn_vs_case.tsv",sep="\t",row.names = F,quote = F)
ca<-aov(lm(formula = dmn~ case,data = c))
# Out:
#   dmn Community_acquired_pneumonia Control_Healthy COVID19
# 1 1   12                           26               1
# 2 2   11                            2              21
# 3 3    2                            1              10

# %%
(summary(ca))
# Out:
#             Df Sum Sq Mean Sq F value Pr(>F)
# case         1 1.9865  1.9865     147 0.0524 .
# Residuals    1 0.0135  0.0135
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
